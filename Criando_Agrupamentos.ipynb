# %% [markdown]
# <a href="https://colab.research.google.com/github/Davholl/Data-Science/blob/master/Criando_Agrupamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv("aluguel.csv", sep=";")

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados.mean()
# Out:
# Quartos           1.771390
# Vagas             1.749059
# Suites            0.665777
# Area            231.901547
# Valor         12952.659715
# Condominio     2388.062424
# IPTU           2364.409585
# dtype: float64

# %%
dados['Valor'].mean()
# Out:
# 12952.659715265761

# %%
bairros = ['Copacabana', 'Barra da Tijuca']

# %%
selecao = dados['Bairro'].isin(bairros)

# %%
dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0         Copacabana
# 2    Barra da Tijuca
# Name: Bairro, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': Int64Index([    2,     7,    20,    22,    30,    35,    41,    44,    49,
#                 59,
#              ...
#              32922, 32923, 32924, 32927, 32939, 32940, 32941, 32942, 32943,
#              32952],
#             dtype='int64', length=6259),
#  'Copacabana': Int64Index([    0,    13,    14,    15,    33,    34,    39,    43,    58,
#                123,
#              ...
#              32790, 32799, 32826, 32838, 32892, 32900, 32916, 32936, 32938,
#              32945],
#             dtype='int64', length=3186)}

# %%
for bairro, data in grupo_bairro:
  print ('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Barra da Tijuca -> 9019.593829923273
# Copacabana -> 4509.83453689168

# %%
grupo_bairro['Valor'].mean().round(2)
# Out:
# Bairro
# Barra da Tijuca    9019.59
# Copacabana         4509.83
# Name: Valor, dtype: float64

# %%
grupo_bairro['Valor'].describe().round()
# Out:
#                   count    mean      std    min     25%     50%     75%  \
# Bairro
# Barra da Tijuca  6256.0  9020.0  30192.0  100.0  2000.0  3500.0  8000.0
# Copacabana       3185.0  4510.0   6413.0  100.0  1900.0  3000.0  4900.0
#
#                       max
# Bairro
# Barra da Tijuca  738197.0
# Copacabana       198000.0

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20,10))

# %%
grupo_bairro['Valor'].std().plot.bar(color = 'blue')
# Out:
# <div id='814106e8-eca1-4355-8e3d-d5b769a62974'></div>
# <div id='0c4b9e68-8110-4a75-9015-438e22fec4d5'></div>
